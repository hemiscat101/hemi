# %% [markdown]
# <a href="https://colab.research.google.com/github/hemiscat101/hemi/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
# !pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.65.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (67.7.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82813 sha256=267bcb50e9155db8040015f6a7387131969ea4be3e687daef5ba44253b92f0c8
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55621 sha256=2a4a5d9b537bb2cf19da20224ee0fc09fc8c5ef82f8f3773668f9ed33188fe67
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.10 umap-learn-0.5.3

# %%
import umap

# %%
fashion_mnist = keras.datasets.fashion_mnist  # Loading the Fashion MNIST data
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()
X_train_full.shape  # every image is represented as a 28 × 28 array
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %%
X_train_full=np.reshape(X_train_full,(60000,784))

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
X_test=np.reshape(X_test,(10000,784))

# %%
X_train_full.dtype
# Out:
# dtype('uint8')

# %%
X_valid, X_train = X_train_full[:5000]/255.0, X_train_full[5000:]/255.0
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress",
               "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
y_train.size
# Out:
# 55000

# %%
y_train
# Out:
# array([4, 0, 7, ..., 3, 0, 5], dtype=uint8)

# %%
one_hot_encode = []
for i in range(60000):
    arr = list(np.zeros(len(class_names), dtype = int))
    arr[y_train_full[i]] = 1
    one_hot_encode.append(arr)
one_hot_encode=np.array(one_hot_encode)

# %%
one_hot_encode_test = []
for i in range(10000):
    arr = list(np.zeros(len(class_names), dtype = int))
    arr[y_test[i]] = 1
    one_hot_encode_test.append(arr)
one_hot_encode_test=np.array(one_hot_encode_test)

# %%
one_hot_encode_valid, one_hot_encode_train = one_hot_encode[:5000], one_hot_encode[5000:]

# %%
def viz_image(index):
    reshaped_image_i=np.reshape(X_train[index],(28,28))
    plt.imshow(reshaped_image_i, cmap='hot', interpolation='nearest')
    plt.axis('off')
    plt.savefig("test.png", bbox_inches='tight')
    plt.show()

# %%
viz_image(0)

# %%
input_ = keras.layers.Input(shape=(784,))
hidden1 = keras.layers.Dense(200, activation="relu", name = "hidden_layer_1")(input_)
hidden2 = keras.layers.Dense(100, activation="relu")(hidden1)
output = keras.layers.Dense(10, activation="sigmoid")(hidden2)

# %%
model = keras.Model(inputs=[input_], outputs=[output])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  hidden_layer_1 (Dense)      (None, 200)               157000
#
#  dense (Dense)               (None, 100)               20100
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 178,110
# Trainable params: 178,110
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd = tf.keras.optimizers.SGD(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer = sgd, metrics=["accuracy"])

# %%
model.fit(X_train,one_hot_encode_train,epochs=10,batch_size=100,
          validation_data=(X_valid, one_hot_encode_valid))
# Out:
# Epoch 1/10
# 550/550 [==============================] - 7s 12ms/step - loss: 1.0328 - accuracy: 0.6782 - val_loss: 0.6639 - val_accuracy: 0.7870
# Epoch 2/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.6144 - accuracy: 0.7967 - val_loss: 0.5508 - val_accuracy: 0.8188
# Epoch 3/10
# 550/550 [==============================] - 6s 12ms/step - loss: 0.5361 - accuracy: 0.8190 - val_loss: 0.4910 - val_accuracy: 0.8374
# Epoch 4/10
# 550/550 [==============================] - 5s 10ms/step - loss: 0.4976 - accuracy: 0.8293 - val_loss: 0.4679 - val_accuracy: 0.8402
# Epoch 5/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.4725 - accuracy: 0.8368 - val_loss: 0.4513 - val_accuracy: 0.8470
# Epoch 6/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.4570 - accuracy: 0.8419 - val_loss: 0.4414 - val_accuracy: 0.8532
# Epoch 7/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.4434 - accuracy: 0.8465 - val_loss: 0.4286 - val_accuracy: 0.8544
# Epoch 8/10
# 550/550 [==============================] - 6s 11ms/step - loss: 0.4315 - accuracy: 0.8504 - val_loss: 0.4219 - val_accuracy: 0.8558
# Epoch 9/10
# 550/550 [==============================] - 5s 9ms/step - loss: 0.4217 - accuracy: 0.8533 - val_loss: 0.4112 - val_accuracy: 0.8594
# Epoch 10/10
# 550/550 [==============================] - 6s 10ms/step - loss: 0.4136 - accuracy: 0.8567 - val_loss: 0.4017 - val_accuracy: 0.8620

# %%
model.evaluate(X_test, one_hot_encode_test, batch_size=None)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 70.2531 - accuracy: 0.8213
# [70.25305938720703, 0.8213000297546387]

# %%
first_hidden_layer_model = tf.keras.Model(inputs=model.input, outputs=model.get_layer("hidden_layer_1").output)
hidden_layer_1_data = first_hidden_layer_model.predict(X_test)
tsne = TSNE(n_components=2, random_state=42)
tsne_embeddings = tsne.fit_transform(hidden_layer_1_data)
plt.figure(figsize=(8, 6))
plt.scatter(tsne_embeddings[:, 0], tsne_embeddings[:, 1], c=np.argmax(one_hot_encode_test, axis=1))
plt.colorbar()
plt.title("t-SNE Visualization of Hidden Layer 1 Data")
plt.xlabel("t-SNE Dimension 1")
plt.ylabel("t-SNE Dimension 2")
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
umap_model = umap.UMAP(n_components=2)
umap_embeddings = umap_model.fit_transform(hidden_layer_1_data)

plt.figure(figsize=(8, 6))
plt.scatter(umap_embeddings[:, 0], umap_embeddings[:, 1], c=np.argmax(one_hot_encode_test, axis=1))
plt.colorbar()
plt.title("UMAP Visualization of Hidden Layer 1 Data")
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.show()

# %%
pca = PCA(n_components=2)
pca_embeddings = pca.fit_transform(hidden_layer_1_data)

plt.figure(figsize=(8, 6))
plt.scatter(pca_embeddings[:, 0], pca_embeddings[:, 1], c=np.argmax(one_hot_encode_test, axis=1))
plt.colorbar()
plt.title("PCA Visualization of Hidden Layer 1 Data")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()

# %%
hidden_layer_1_data.shape
# Out:
# (10000, 200)

# %%
def viz_data(index):
    reshaped_data_i=np.reshape(hidden_layer_1_data[index],(20,10))
    plt.imshow(reshaped_data_i, cmap='hot', interpolation='nearest')
    plt.axis('off')
    plt.savefig("test.png", bbox_inches='tight')
    plt.show()
viz_data(0)

# %%
import numpy as np
def random_batch(X, y, batch_size=32):
    idx = np.random.randint(len(X), size=batch_size)
    return X[idx], y[idx]

def print_status_bar(iteration, total, loss, metrics=None):
    metrics = " - ".join(["{}: {:.4f}".format(m.name, m.result())
                         for m in [loss] + (metrics or [])])
    end = "" if iteration < total else "\n"
    print("\r{}/{} - ".format(iteration, total) + metrics,
           end=end)

n_epochs = 5
batch_size = 32
n_steps = len(X_train) // batch_size
optimizer = keras.optimizers.SGD(lr=0.01)
loss_fn = keras.losses.SparseCategoricalCrossentropy()
mean_loss = keras.metrics.Mean()
metrics = [keras.metrics.MeanAbsoluteError()]


for epoch in range(1, n_epochs + 1):
    print("Epoch {}/{}".format(epoch, n_epochs))
    for step in range(1, n_steps + 1):
        X_batch, y_batch = random_batch(X_train, y_train)
        with tf.GradientTape() as tape:
             y_pred = model(X_batch, training=True)
             main_loss = tf.reduce_mean(loss_fn(y_batch, y_pred))
             loss = tf.add_n([main_loss] + model.losses)
        gradients = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(gradients, model.trainable_variables))
        mean_loss(loss)
        for metric in metrics:
            metric(y_batch[1], y_pred)
        print_status_bar(step * batch_size, len(y_train), mean_loss, metrics)
    print_status_bar(len(y_train), len(y_train), mean_loss, metrics)
    for metric in [mean_loss] + metrics:
        metric.reset_states()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/5
# 55000/55000 - mean: 0.4154 - mean_absolute_error: 4.1995
# Epoch 2/5
# 55000/55000 - mean: 0.3972 - mean_absolute_error: 4.1155
# Epoch 3/5
# 55000/55000 - mean: 0.3779 - mean_absolute_error: 3.9443
# Epoch 4/5
# 55000/55000 - mean: 0.3701 - mean_absolute_error: 4.1445
# Epoch 5/5
# 55000/55000 - mean: 0.3600 - mean_absolute_error: 4.1306
